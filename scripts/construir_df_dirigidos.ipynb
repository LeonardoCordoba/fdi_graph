# %%
import pandas as pd
import numpy as np
import math
#import networkx as nx

# %%
df = pd.read_csv("fdi_paises.csv", encoding="latin-1")

# %%
df_2003 = df[df["Year"]==2003]
df_2004 = df[df["Year"]==2004]
df_2005 = df[df["Year"]==2005]
df_2006 = df[df["Year"]==2006]
df_2007 = df[df["Year"]==2007]
df_2008 = df[df["Year"]==2008]
df_2009 = df[df["Year"]==2009]
df_2010 = df[df["Year"]==2010]
df_2011 = df[df["Year"]==2011]
df_2012 = df[df["Year"]==2012]
df_2013 = df[df["Year"]==2013]

# %%
240**2
# Out:
# 57600

# %%
from itertools import product
countries = np.unique(np.union1d(df_2003["Reporting country"],df_2003["Partner country"]))
final_df_2003 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2003["Value"] = 0

# %%
import math

df_2003_in = df_2003[df_2003["FLOW"]=="IN"]
df_2003_out = df_2003[df_2003["FLOW"]=="OUT"]

for i in final_df_2003["Reporting country"].unique():
    print(i)
    for j in final_df_2003["Partner country"].unique():
        if i != j:
            value_a = df_2003_in.loc[(df_2003_in["Reporting country"]==j)&(df_2003_in["Partner country"]==i), "Value"]
            value_b = df_2003_out.loc[(df_2003_out["Reporting country"]==i)&(df_2003_out["Partner country"]==j), "Value"]
            value_c = df_2003_in.loc[(df_2003_in["Reporting country"]==i)&(df_2003_in["Partner country"]==j), "Value"]
            value_d = df_2003_out.loc[(df_2003_out["Reporting country"]==j)&(df_2003_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2003.loc[(final_df_2003["Reporting country"]==i)&(final_df_2003["Partner country"]==j),"Value"] = value
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
# Chile y bel
print(df_2003.loc[(df_2003["Reporting country"]=="Chile")&(df_2003["Partner country"]=="Belgium"), ["Partner country","Reporting country","FLOW", "Value"]])
print(df_2003.loc[(df_2003["Reporting country"]=="Belgium")&(df_2003["Partner country"]=="Chile"), ["Partner country","Reporting country","FLOW", "Value"]])
print(final_df_2003.loc[(final_df_2003["Reporting country"]=="Chile") & (final_df_2003["Partner country"]=="Belgium")])
print(final_df_2003.loc[(final_df_2003["Reporting country"]=="Belgium") & (final_df_2003["Partner country"]=="Chile")])
# Out:
# Empty DataFrame
# Columns: [Partner country, Reporting country, FLOW, Value]
# Index: []
#       Partner country Reporting country FLOW   Value
# 23551           Chile           Belgium   IN   1.130
# 23561           Chile           Belgium  OUT  22.594
#       Reporting country Partner country  Value
# 10100             Chile         Belgium   1.13
#      Reporting country Partner country   Value
# 4842           Belgium           Chile  22.594

# %%
# Belgium y Aus
print(df_2003.loc[(df_2003["Reporting country"]=="Belgium")&(df_2003["Partner country"]=="Australia"), ["Partner country","Reporting country","FLOW", "Value"]])
print(df_2003.loc[(df_2003["Reporting country"]=="Australia")&(df_2003["Partner country"]=="Belgium"), ["Partner country","Reporting country","FLOW", "Value"]])
print(final_df_2003.loc[(final_df_2003["Reporting country"]=="Belgium") & (final_df_2003["Partner country"]=="Australia")])
print(final_df_2003.loc[(final_df_2003["Reporting country"]=="Australia") & (final_df_2003["Partner country"]=="Belgium")])
# Out:
#      Partner country Reporting country FLOW    Value
# 6661       Australia           Belgium   IN   75.689
# 6671       Australia           Belgium  OUT -237.235
#       Partner country Reporting country FLOW    Value
# 11203         Belgium         Australia   IN  672.721
# 11213         Belgium         Australia  OUT   96.010
#      Reporting country Partner country    Value
# 4812           Belgium       Australia  672.721
#      Reporting country Partner country    Value
# 2900         Australia         Belgium  408.934

# %%
# Mexico y Aus
print(df_2003.loc[(df_2003["Reporting country"]=="Mexico")&(df_2003["Partner country"]=="Australia"), ["Partner country","Reporting country","FLOW", "Value"]])
print(df_2003.loc[(df_2003["Reporting country"]=="Australia")&(df_2003["Partner country"]=="Mexico"), ["Partner country","Reporting country","FLOW", "Value"]])
print(final_df_2003.loc[(final_df_2003["Reporting country"]=="Mexico") & (final_df_2003["Partner country"]=="Australia")])
print(final_df_2003.loc[(final_df_2003["Reporting country"]=="Australia") & (final_df_2003["Partner country"]=="Mexico")])
# Out:
#      Partner country Reporting country FLOW  Value
# 6939       Australia            Mexico   IN  6.003
#       Partner country Reporting country FLOW  Value
# 77789          Mexico         Australia   IN    0.0
# 77799          Mexico         Australia  OUT    NaN
#       Reporting country Partner country  Value
# 33372            Mexico       Australia    0.0
#      Reporting country Partner country  Value
# 3019         Australia          Mexico  6.003

# %%
final_df_2003.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2003.csv", encoding="latin-1")

# %%
final_df_2004 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2004["Value"] = 0

df_2004_in = df_2004[df_2004["FLOW"]=="IN"]
df_2004_out = df_2004[df_2004["FLOW"]=="OUT"]

for i in final_df_2004["Reporting country"].unique():
    print(i)
    for j in final_df_2004["Partner country"].unique():
        if i != j:
            value_a = df_2004_in.loc[(df_2004_in["Reporting country"]==j)&(df_2004_in["Partner country"]==i), "Value"]
            value_b = df_2004_out.loc[(df_2004_out["Reporting country"]==i)&(df_2004_out["Partner country"]==j), "Value"]
            value_c = df_2004_in.loc[(df_2004_in["Reporting country"]==i)&(df_2004_in["Partner country"]==j), "Value"]
            value_d = df_2004_out.loc[(df_2004_out["Reporting country"]==j)&(df_2004_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2004.loc[(final_df_2004["Reporting country"]==i)&(final_df_2004["Partner country"]==j),"Value"] = value
            
final_df_2004.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2004.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2004["Value"].sum()/df_2004["Value"].abs().sum()*100
# Out:
# 99.78533851752428

# %%
final_df_2005 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2005["Value"] = 0

df_2005_in = df_2005[df_2005["FLOW"]=="IN"]
df_2005_out = df_2005[df_2005["FLOW"]=="OUT"]

for i in final_df_2005["Reporting country"].unique():
    print(i)
    for j in final_df_2005["Partner country"].unique():
        if i != j:
            value_a = df_2005_in.loc[(df_2005_in["Reporting country"]==j)&(df_2005_in["Partner country"]==i), "Value"]
            value_b = df_2005_out.loc[(df_2005_out["Reporting country"]==i)&(df_2005_out["Partner country"]==j), "Value"]
            value_c = df_2005_in.loc[(df_2005_in["Reporting country"]==i)&(df_2005_in["Partner country"]==j), "Value"]
            value_d = df_2005_out.loc[(df_2005_out["Reporting country"]==j)&(df_2005_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2005.loc[(final_df_2005["Reporting country"]==i)&(final_df_2005["Partner country"]==j),"Value"] = value

final_df_2005.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2005.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2005["Value"].sum()/df_2005["Value"].abs().sum()*100
# Out:
# 100.00000000000004

# %%
final_df_2006 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2006["Value"] = 0

df_2006_in = df_2006[df_2006["FLOW"]=="IN"]
df_2006_out = df_2006[df_2006["FLOW"]=="OUT"]

for i in final_df_2006["Reporting country"].unique():
    print(i)
    for j in final_df_2006["Partner country"].unique():
        if i != j:
            value_a = df_2006_in.loc[(df_2006_in["Reporting country"]==j)&(df_2006_in["Partner country"]==i), "Value"]
            value_b = df_2006_out.loc[(df_2006_out["Reporting country"]==i)&(df_2006_out["Partner country"]==j), "Value"]
            value_c = df_2006_in.loc[(df_2006_in["Reporting country"]==i)&(df_2006_in["Partner country"]==j), "Value"]
            value_d = df_2006_out.loc[(df_2006_out["Reporting country"]==j)&(df_2006_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2006.loc[(final_df_2006["Reporting country"]==i)&(final_df_2006["Partner country"]==j),"Value"] = value

final_df_2006.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2006.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2006["Value"].sum()/df_2006["Value"].abs().sum()*100
# Out:
# 100.00000000000017

# %%
final_df_2007 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2007["Value"] = 0

df_2007_in = df_2007[df_2007["FLOW"]=="IN"]
df_2007_out = df_2007[df_2007["FLOW"]=="OUT"]

for i in final_df_2007["Reporting country"].unique():
    print(i)
    for j in final_df_2007["Partner country"].unique():
        if i != j:
            value_a = df_2007_in.loc[(df_2007_in["Reporting country"]==j)&(df_2007_in["Partner country"]==i), "Value"]
            value_b = df_2007_out.loc[(df_2007_out["Reporting country"]==i)&(df_2007_out["Partner country"]==j), "Value"]
            value_c = df_2007_in.loc[(df_2007_in["Reporting country"]==i)&(df_2007_in["Partner country"]==j), "Value"]
            value_d = df_2007_out.loc[(df_2007_out["Reporting country"]==j)&(df_2007_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2007.loc[(final_df_2007["Reporting country"]==i)&(final_df_2007["Partner country"]==j),"Value"] = value

final_df_2007.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2007.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2007["Value"].sum()/df_2007["Value"].abs().sum()*100
# Out:
# 99.99999999999993

# %%
final_df_2008 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2008["Value"] = 0

df_2008_in = df_2008[df_2008["FLOW"]=="IN"]
df_2008_out = df_2008[df_2008["FLOW"]=="OUT"]

for i in final_df_2008["Reporting country"].unique():
    print(i)
    for j in final_df_2008["Partner country"].unique():
        if i != j:
            value_a = df_2008_in.loc[(df_2008_in["Reporting country"]==j)&(df_2008_in["Partner country"]==i), "Value"]
            value_b = df_2008_out.loc[(df_2008_out["Reporting country"]==i)&(df_2008_out["Partner country"]==j), "Value"]
            value_c = df_2008_in.loc[(df_2008_in["Reporting country"]==i)&(df_2008_in["Partner country"]==j), "Value"]
            value_d = df_2008_out.loc[(df_2008_out["Reporting country"]==j)&(df_2008_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2008.loc[(final_df_2008["Reporting country"]==i)&(final_df_2008["Partner country"]==j),"Value"] = value

final_df_2008.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2008.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2008["Value"].sum()/df_2008["Value"].abs().sum()*100
# Out:
# 99.99852957853058

# %%
final_df_2009 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2009["Value"] = 0

df_2009_in = df_2009[df_2009["FLOW"]=="IN"]
df_2009_out = df_2009[df_2009["FLOW"]=="OUT"]

for i in final_df_2009["Reporting country"].unique():
    print(i)
    for j in final_df_2009["Partner country"].unique():
        if i != j:
            value_a = df_2009_in.loc[(df_2009_in["Reporting country"]==j)&(df_2009_in["Partner country"]==i), "Value"]
            value_b = df_2009_out.loc[(df_2009_out["Reporting country"]==i)&(df_2009_out["Partner country"]==j), "Value"]
            value_c = df_2009_in.loc[(df_2009_in["Reporting country"]==i)&(df_2009_in["Partner country"]==j), "Value"]
            value_d = df_2009_out.loc[(df_2009_out["Reporting country"]==j)&(df_2009_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2009.loc[(final_df_2009["Reporting country"]==i)&(final_df_2009["Partner country"]==j),"Value"] = value

final_df_2009.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2009.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2009["Value"].sum()/df_2009["Value"].abs().sum()*100
# Out:
# 99.99999999999987

# %%
final_df_2010 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2010["Value"] = 0

df_2010_in = df_2010[df_2010["FLOW"]=="IN"]
df_2010_out = df_2010[df_2010["FLOW"]=="OUT"]

for i in final_df_2010["Reporting country"].unique():
    print(i)
    for j in final_df_2010["Partner country"].unique():
        if i != j:
            value_a = df_2010_in.loc[(df_2010_in["Reporting country"]==j)&(df_2010_in["Partner country"]==i), "Value"]
            value_b = df_2010_out.loc[(df_2010_out["Reporting country"]==i)&(df_2010_out["Partner country"]==j), "Value"]
            value_c = df_2010_in.loc[(df_2010_in["Reporting country"]==i)&(df_2010_in["Partner country"]==j), "Value"]
            value_d = df_2010_out.loc[(df_2010_out["Reporting country"]==j)&(df_2010_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2010.loc[(final_df_2010["Reporting country"]==i)&(final_df_2010["Partner country"]==j),"Value"] = value

final_df_2010.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2010.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2010["Value"].sum()/df_2010["Value"].abs().sum()*100
# Out:
# 99.99999999999969

# %%
final_df_2011 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2011["Value"] = 0

df_2011_in = df_2011[df_2011["FLOW"]=="IN"]
df_2011_out = df_2011[df_2011["FLOW"]=="OUT"]

for i in final_df_2011["Reporting country"].unique():
    print(i)
    for j in final_df_2011["Partner country"].unique():
        if i != j:
            value_a = df_2011_in.loc[(df_2011_in["Reporting country"]==j)&(df_2011_in["Partner country"]==i), "Value"]
            value_b = df_2011_out.loc[(df_2011_out["Reporting country"]==i)&(df_2011_out["Partner country"]==j), "Value"]
            value_c = df_2011_in.loc[(df_2011_in["Reporting country"]==i)&(df_2011_in["Partner country"]==j), "Value"]
            value_d = df_2011_out.loc[(df_2011_out["Reporting country"]==j)&(df_2011_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2011.loc[(final_df_2011["Reporting country"]==i)&(final_df_2011["Partner country"]==j),"Value"] = value

final_df_2011.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2011.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2011["Value"].sum()/df_2011["Value"].abs().sum()*100
# Out:
# 100.00000000000031

# %%
final_df_2012 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2012["Value"] = 0

df_2012_in = df_2012[df_2012["FLOW"]=="IN"]
df_2012_out = df_2012[df_2012["FLOW"]=="OUT"]

for i in final_df_2012["Reporting country"].unique():
    print(i)
    for j in final_df_2012["Partner country"].unique():
        if i != j:
            value_a = df_2012_in.loc[(df_2012_in["Reporting country"]==j)&(df_2012_in["Partner country"]==i), "Value"]
            value_b = df_2012_out.loc[(df_2012_out["Reporting country"]==i)&(df_2012_out["Partner country"]==j), "Value"]
            value_c = df_2012_in.loc[(df_2012_in["Reporting country"]==i)&(df_2012_in["Partner country"]==j), "Value"]
            value_d = df_2012_out.loc[(df_2012_out["Reporting country"]==j)&(df_2012_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2012.loc[(final_df_2012["Reporting country"]==i)&(final_df_2012["Partner country"]==j),"Value"] = value

final_df_2012.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2012.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2012["Value"].sum()/df_2012["Value"].abs().sum()*100
# Out:
# 100.00000000000009

# %%
final_df_2013 = pd.DataFrame(list(product(countries, countries)), columns=['Reporting country', 'Partner country'])
final_df_2013["Value"] = 0

df_2013_in = df_2013[df_2013["FLOW"]=="IN"]
df_2013_out = df_2013[df_2013["FLOW"]=="OUT"]

for i in final_df_2013["Reporting country"].unique():
    print(i)
    for j in final_df_2013["Partner country"].unique():
        if i != j:
            value_a = df_2013_in.loc[(df_2013_in["Reporting country"]==j)&(df_2013_in["Partner country"]==i), "Value"]
            value_b = df_2013_out.loc[(df_2013_out["Reporting country"]==i)&(df_2013_out["Partner country"]==j), "Value"]
            value_c = df_2013_in.loc[(df_2013_in["Reporting country"]==i)&(df_2013_in["Partner country"]==j), "Value"]
            value_d = df_2013_out.loc[(df_2013_out["Reporting country"]==j)&(df_2013_out["Partner country"]==i), "Value"]
            
            if value_a.isnull().values == False:
                if math.isnan(value_a.item()) == False:
                    if value_a.size == 0:
                        value_a = pd.Series([0])
            else:
                value_a = pd.Series([0])
                
            if value_b.isnull().values == False:
                if math.isnan(value_b.item()) == False:
                    if value_b.size == 0:
                        value_b = pd.Series([0])
            else:
                value_b = pd.Series([0])
                
            if value_c.isnull().values == False:
                if math.isnan(value_c.item()) == False:
                    if value_c.size == 0:
                        value_c = pd.Series([0])
            else:
                value_c = pd.Series([0])
                
            if value_d.isnull().values == False:
                if math.isnan(value_d.item()) == False:
                    if value_d.size == 0:
                        value_d = pd.Series([0])
            else:
                value_d = pd.Series([0])
            
            if value_a.values > 0:
                in_ji = value_a.values
            else:
                in_ji = 0
                
            if value_b.values > 0:
                out_ij = value_b.values
            else:
                out_ij = 0
                
            if value_c.values < 0:
                in_ij = value_c.values*(-1)
            else:
                in_ij = 0
            
            if value_d.values < 0:
                out_ji = value_d.values*(-1)
            else:
                out_ji = 0
                
            value = in_ji + out_ij + in_ij + out_ji
            final_df_2013.loc[(final_df_2013["Reporting country"]==i)&(final_df_2013["Partner country"]==j),"Value"] = value

final_df_2013.to_csv("C:\\Users\\vsilecor.NET01\\Downloads\\grafos-20180118T165154Z-001\\grafos\\fuentes\\df_dirigido_2013.csv", encoding="latin-1")
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia (Kampuchea)
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Côte d'Ivoire
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Franc zone
# French Polynesia
# ...

# %%
final_df_2013["Value"].sum()/df_2013["Value"].abs().sum()*100
# Out:
# 99.99999999999997
