# %%
import pandas as pd

# %%
df = pd.read_csv("FDI_FLOW_PARTNER_18122017211603156.csv")

# %%
df.head()
# Out:
#   FLOW Type of FDI  PC Partner country  CUR           Currency  COU  \
# 0   IN      Inward  B5   ACP countries  SUB  Reported currency  AUT
# 1   IN      Inward  B5   ACP countries  SUB  Reported currency  AUT
# 2   IN      Inward  B5   ACP countries  SUB  Reported currency  AUT
# 3   IN      Inward  B5   ACP countries  SUB  Reported currency  AUT
# 4   IN      Inward  B5   ACP countries  SUB  Reported currency  AUT
#
#   Reporting country   YEA  Year Unit Code  Unit  PowerCode Code PowerCode  \
# 0           Austria  2003  2003       EUR  Euro               6  Millions
# 1           Austria  2004  2004       EUR  Euro               6  Millions
# 2           Austria  2005  2005       EUR  Euro               6  Millions
# 3           Austria  2006  2006       EUR  Euro               6  Millions
# 4           Austria  2007  2007       EUR  Euro               6  Millions
#
#    Reference Period Code  Reference Period  Value Flag Codes Flags
# ...

# %%
df = pd.DataFrame(df)

# %%
df.columns
# Out:
# Index(['FLOW', 'Type of FDI', 'PC', 'Partner country', 'CUR', 'Currency',
#        'COU', 'Reporting country', 'YEA', 'Year', 'Unit Code', 'Unit',
#        'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
df["FLOW"]
# Out:
# 0          IN
# 1          IN
# 2          IN
# 3          IN
# 4          IN
# 5          IN
# 6          IN
# 7          IN
# 8          IN
# 9          IN
# 10         IN
# 11        OUT
# 12        OUT
# 13        OUT
# 14        OUT
# 15        OUT
# 16        OUT
# 17        OUT
# 18        OUT
# 19        OUT
# 20        OUT
# 21        OUT
# 22         IN
# 23         IN
# 24         IN
# 25         IN
# 26         IN
# 27         IN
# 28         IN
# 29         IN
#          ...
# 335024     IN
# 335025     IN
# 335026     IN
# 335027     IN
# 335028     IN
# 335029     IN
# 335030     IN
# 335031     IN
# 335032     IN
# 335033     IN
# 335034     IN
# 335035     IN
# 335036     IN
# 335037     IN
# 335038     IN
# 335039     IN
# 335040     IN
# 335041     IN
# 335042     IN
# 335043     IN
# 335044     IN
# 335045     IN
# 335046     IN
# 335047     IN
# 335048     IN
# 335049     IN
# 335050     IN
# 335051     IN
# 335052     IN
# 335053     IN
# ...

# %%
df[['Partner country', 'Reporting country']]
# Out:
#        Partner country Reporting country
# 0        ACP countries           Austria
# 1        ACP countries           Austria
# 2        ACP countries           Austria
# 3        ACP countries           Austria
# 4        ACP countries           Austria
# 5        ACP countries           Austria
# 6        ACP countries           Austria
# 7        ACP countries           Austria
# 8        ACP countries           Austria
# 9        ACP countries           Austria
# 10       ACP countries           Austria
# 11       ACP countries           Austria
# 12       ACP countries           Austria
# 13       ACP countries           Austria
# 14       ACP countries           Austria
# 15       ACP countries           Austria
# 16       ACP countries           Austria
# 17       ACP countries           Austria
# 18       ACP countries           Austria
# 19       ACP countries           Austria
# 20       ACP countries           Austria
# 21       ACP countries           Austria
# ...

# %%
df[(df['Partner country'] == "Australia") & (df['Reporting country'] == "Chile") & (df['Year'] == 2006)]
# Out:
#       FLOW Type of FDI   PC Partner country  CUR           Currency  COU  \
# 21440   IN      Inward  AUS       Australia  SUB  Reported currency  CHL
# 21448  OUT     Outward  AUS       Australia  SUB  Reported currency  CHL
# 21456   IN      Inward  AUS       Australia  USD          US Dollar  CHL
# 21464  OUT     Outward  AUS       Australia  USD          US Dollar  CHL
#
#       Reporting country   YEA  Year Unit Code       Unit  PowerCode Code  \
# 21440             Chile  2006  2006       USD  US Dollar               6
# 21448             Chile  2006  2006       USD  US Dollar               6
# 21456             Chile  2006  2006       USD  US Dollar               6
# 21464             Chile  2006  2006       USD  US Dollar               6
#
#       PowerCode  Reference Period Code  Reference Period  Value Flag Codes  \
# 21440  Millions                    NaN               NaN   92.0        NaN
# 21448  Millions                    NaN               NaN    0.0          Z
# ...

# %%
df2 = df[df['CUR'] == "USD"]

# %%
df2.columns
# Out:
# Index(['FLOW', 'Type of FDI', 'PC', 'Partner country', 'CUR', 'Currency',
#        'COU', 'Reporting country', 'YEA', 'Year', 'Unit Code', 'Unit',
#        'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
import networkx as nx

# %%
df2["Value"].quantile([0.1,0.25,0.5,0.75,0.9])
# Out:
# 0.10     -2.25900
# 0.25      0.00000
# 0.50      0.00000
# 0.75      6.25275
# 0.90    478.89100
# Name: Value, dtype: float64

# %%
df2.distinct("Partner country")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-202-2ddfebad29ee> in <module>()
# ----> 1 df2.distinct("Partner country")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'distinct'

# %%
df2[["Partner country","Value"]].groupby("Partner country").sum()
# Out:
#                                                           Value
# Partner country
# ACP countries                                         98497.686
# AFRICA                                               240859.176
# AFRICA Unallocated                                    21535.631
# AMERICA                                             4753605.203
# AMERICA (Excluding OECD countries)                  1514086.581
# AMERICA Unallocated                                  213055.651
# ASEAN countries                                      496958.999
# ASIA                                                1749137.309
# ASIA (Excluding OECD countries)                     1378814.777
# ASIA Unallocated                                      25038.220
# Afghanistan                                             357.552
# Africa excluding North African countries- Unall...    16602.841
# African ACP countries                                121286.874
# ...

# %%
paises = ["United States", "Australia", "Chile"]
df_g = df2[(df2['Year'] == 2006)]

# %%
G=nx.from_pandas_dataframe(df_g, source="Partner country", target="Reporting country", edge_attr= ["Year", "Value"])

# %%
 import matplotlib.pyplot as plt

# %%
#G = nx.petersen_graph()
plt.subplot(121)

# %%
nx.draw(G, with_labels=True, font_weight='bold')
plt.subplot(122)
# Out:
# /home/usuario/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   draw_networkx(G, pos=pos, ax=ax, **kwds)
# /home/usuario/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   labeling, titles, and many other drawing features.
# /home/usuario/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
nx.draw_shell(G, with_labels=True, font_weight='bold')
# Out:
# /home/usuario/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   draw_networkx(G, pos=pos, ax=ax, **kwds)
# /home/usuario/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   labeling, titles, and many other drawing features.
# /home/usuario/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
df_g
# Out:
#        FLOW Type of FDI  PC Partner country  CUR   Currency  COU  \
# 25       IN      Inward  B5   ACP countries  USD  US Dollar  AUT
# 36      OUT     Outward  B5   ACP countries  USD  US Dollar  AUT
# 67       IN      Inward  B5   ACP countries  USD  US Dollar  BEL
# 77      OUT     Outward  B5   ACP countries  USD  US Dollar  BEL
# 107      IN      Inward  B5   ACP countries  USD  US Dollar  CZE
# 117     OUT     Outward  B5   ACP countries  USD  US Dollar  CZE
# 147      IN      Inward  B5   ACP countries  USD  US Dollar  DNK
# 157     OUT     Outward  B5   ACP countries  USD  US Dollar  DNK
# 193     OUT     Outward  B5   ACP countries  USD  US Dollar  FIN
# 223      IN      Inward  B5   ACP countries  USD  US Dollar  FRA
# 233     OUT     Outward  B5   ACP countries  USD  US Dollar  FRA
# 263      IN      Inward  B5   ACP countries  USD  US Dollar  DEU
# 273     OUT     Outward  B5   ACP countries  USD  US Dollar  DEU
# ...
